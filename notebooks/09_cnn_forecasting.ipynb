# %% [markdown]
# # CNN 기반 예측

# %% [markdown]
# # ✅ 🔹 CNN 기반 테슬라 주가 예측 코드

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# 📌 1️⃣ 테슬라(TSLA) 주가 데이터 다운로드 (최근 2년치)
df = yf.download("TSLA", start="2022-01-01", end="2024-01-01")
df = df.reset_index()

# 📌 2️⃣ Feature 생성: 날짜(Day)를 숫자로 변환
df["Day"] = np.arange(len(df))

# 📌 3️⃣ 독립 변수(X) 및 종속 변수(y) 정의
X = df[["Day"]].values  # 날짜(Day)를 입력 변수로 사용
y = df["Close"].values  # 종가(Close)를 예측할 목표 변수로 사용

# 데이터 정규화 (MinMaxScaler 사용)
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# 📌 4️⃣ 데이터 분할 (80% 학습, 20% 테스트)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)

# CNN 입력 형식 변환 (samples, time steps, features)
X_train = X_train.reshape(X_train.shape[0], 1, 1)
X_test = X_test.reshape(X_test.shape[0], 1, 1)

# 📌 5️⃣ CNN 모델 생성
model = Sequential([
    Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(1, 1)),  # CNN 레이어
    Flatten(),  # 차원 축소
    Dense(50, activation='relu'),  # Fully Connected Layer
    Dense(1)  # 출력층
])

# 모델 컴파일 (손실함수: MSE, 최적화 알고리즘: Adam)
model.compile(optimizer='adam', loss='mse')

# 📌 6️⃣ 모델 학습
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# 📌 7️⃣ 예측 수행
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# 예측 데이터 역정규화
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler_y.inverse_transform(y_test.reshape(-1, 1))

# 📌 8️⃣ 성능 평가
train_mse = mean_squared_error(y_train_actual, y_train_pred)
test_mse = mean_squared_error(y_test_actual, y_test_pred)
train_r2 = r2_score(y_train_actual, y_train_pred)
test_r2 = r2_score(y_test_actual, y_test_pred)

print(f"📌 Training MSE: {train_mse:.4f}, R²: {train_r2:.4f}")
print(f"📌 Test MSE: {test_mse:.4f}, R²: {test_r2:.4f}")

# 📌 9️⃣ 결과 시각화 (훈련 데이터 예측 vs 실제값)
plt.figure(figsize=(12, 5))
plt.plot(df["Date"].iloc[:len(X_train)], y_train_actual, label="Actual (Training)", color="black")
plt.plot(df["Date"].iloc[:len(X_train)], y_train_pred, label="Predicted (Training)", color="blue", linestyle="--")
plt.title("Tesla Stock Price Prediction using CNN (Without Sliding Window) - Training Phase")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# 📌 🔟 결과 시각화 (테스트 데이터 예측 vs 실제값)
plt.figure(figsize=(12, 5))
plt.plot(df["Date"].iloc[len(X_train):], y_test_actual, label="Actual (Test)", color="black")
plt.plot(df["Date"].iloc[len(X_train):], y_test_pred, label="Predicted (Test)", color="red", linestyle="--")
plt.title("Tesla Stock Price Prediction using CNN (Without Sliding Window) - Test Phase")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.2036 - val_loss: 0.0182
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0934 - val_loss: 0.0130
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0724 - val_loss: 0.0065
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0575 - val_loss: 0.0044
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0407 - val_loss: 0.0088
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0338 - val_loss: 0.0128
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0279 - val_loss: 0.0335
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0226 - val_loss: 0.0220
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0227 - val_loss: 0.0237
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0239 - val_loss: 0.0429
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0211 - val_loss: 0.0329
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0229 - val_loss: 0.0413
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0209 - val_loss: 0.0294
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0218 - val_loss: 0.0350
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0217 - val_loss: 0.0289
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0218 - val_loss: 0.0225
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0213 - val_loss: 0.0270
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0220 - val_loss: 0.0150
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - val_loss: 0.0239
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - val_loss: 0.0224
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0206 - val_loss: 0.0233
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - val_loss: 0.0209
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0188 - val_loss: 0.0180
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0204 - val_loss: 0.0239
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - val_loss: 0.0172
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0199 - val_loss: 0.0217
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - val_loss: 0.0096
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0206 - val_loss: 0.0154
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0203 - val_loss: 0.0126
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0180 - val_loss: 0.0102
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0187 - val_loss: 0.0093
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - val_loss: 0.0110
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0175 - val_loss: 0.0073
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - val_loss: 0.0087
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - val_loss: 0.0099
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0184 - val_loss: 0.0044
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0174 - val_loss: 0.0062
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0193 - val_loss: 0.0068
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0175 - val_loss: 0.0101
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - val_loss: 0.0077
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189 - val_loss: 0.0064
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0166 - val_loss: 0.0048
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169 - val_loss: 0.0051
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - val_loss: 0.0046
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - val_loss: 0.0048
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0157 - val_loss: 0.0048
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0174 - val_loss: 0.0048
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0172 - val_loss: 0.0049
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0161 - val_loss: 0.0049
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0162 - val_loss: 0.0070
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0174 - val_loss: 0.0051
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0167 - val_loss: 0.0054
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0165 - val_loss: 0.0067
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0153 - val_loss: 0.0072
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - val_loss: 0.0057
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - val_loss: 0.0077
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0154 - val_loss: 0.0074
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0145 - val_loss: 0.0074
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0152 - val_loss: 0.0071
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0157 - val_loss: 0.0088
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - val_loss: 0.0076
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0145 - val_loss: 0.0113
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - val_loss: 0.0089
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0154 - val_loss: 0.0140
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - val_loss: 0.0095
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - val_loss: 0.0150
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0154 - val_loss: 0.0116
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0151 - val_loss: 0.0200
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0147 - val_loss: 0.0094
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0148 - val_loss: 0.0189
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0145 - val_loss: 0.0103
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0149 - val_loss: 0.0181
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0150 - val_loss: 0.0192
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0152 - val_loss: 0.0176
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0152 - val_loss: 0.0162
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - val_loss: 0.0131
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0147 - val_loss: 0.0160
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - val_loss: 0.0208
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - val_loss: 0.0143
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - val_loss: 0.0161
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - val_loss: 0.0202
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144 - val_loss: 0.0325
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0138 - val_loss: 0.0204
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - val_loss: 0.0256
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - val_loss: 0.0270
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - val_loss: 0.0335
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134 - val_loss: 0.0290
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - val_loss: 0.0246
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - val_loss: 0.0228
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - val_loss: 0.0322
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - val_loss: 0.0163
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - val_loss: 0.0231
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - val_loss: 0.0231
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - val_loss: 0.0213
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125 - val_loss: 0.0320
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121 - val_loss: 0.0232
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - val_loss: 0.0494
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - val_loss: 0.0329
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - val_loss: 0.0244
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - val_loss: 0.0259
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 📌 Training MSE: 1006.3470, R²: 0.7322
# 📌 Test MSE: 2208.7845, R²: -6.2751

# %% [markdown]
# # ✅ 🚀 Sliding Window 적용된 CNN 기반 테슬라 주가 예측 코드:

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score

# 📌 1️⃣ 테슬라(TSLA) 주가 데이터 다운로드 (최근 2년치)
df = yf.download("TSLA", start="2022-01-01", end="2024-01-01")
df = df.reset_index()

# 📌 2️⃣ 슬라이딩 윈도우 함수 생성
def create_sliding_window_data(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i : i + window_size])  # 과거 window_size만큼의 데이터
        y.append(data[i + window_size])  # 예측할 값 (다음날 종가)
    return np.array(X), np.array(y)

# 📌 3️⃣ 데이터 정규화 (MinMaxScaler 사용)
scaler = MinMaxScaler()
scaled_close = scaler.fit_transform(df["Close"].values.reshape(-1, 1))

# 슬라이딩 윈도우 적용
window_size = 10  # 과거 10일 데이터로 미래 1일 예측
X, y = create_sliding_window_data(scaled_close, window_size)

# 📌 4️⃣ 데이터 분할 (80% 학습, 20% 테스트)
split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# 입력 데이터를 CNN 입력 형식 (samples, time steps, features)으로 변환
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# 📌 5️⃣ CNN 모델 생성
model = Sequential([
    Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(window_size, 1)),  # CNN 레이어
    Flatten(),  # 차원 축소
    Dense(50, activation='relu'),  # Fully Connected Layer
    Dense(1)  # 출력층
])

# 모델 컴파일 (손실함수: MSE, 최적화 알고리즘: Adam)
model.compile(optimizer='adam', loss='mse')

# 📌 6️⃣ 모델 학습
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# 📌 7️⃣ 예측 수행
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# 예측 데이터 역정규화
y_train_pred = scaler.inverse_transform(y_train_pred)
y_test_pred = scaler.inverse_transform(y_test_pred)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# 📌 8️⃣ 성능 평가
train_mse = mean_squared_error(y_train_actual, y_train_pred)
test_mse = mean_squared_error(y_test_actual, y_test_pred)
train_r2 = r2_score(y_train_actual, y_train_pred)
test_r2 = r2_score(y_test_actual, y_test_pred)

print(f"📌 Training MSE: {train_mse:.4f}, R²: {train_r2:.4f}")
print(f"📌 Test MSE: {test_mse:.4f}, R²: {test_r2:.4f}")

# 📌 9️⃣ 결과 시각화 (훈련 데이터 예측 vs 실제값)
plt.figure(figsize=(12, 5))
plt.plot(df["Date"].iloc[window_size:split_index+window_size], y_train_actual, label="Actual (Training)", color="black")
plt.plot(df["Date"].iloc[window_size:split_index+window_size], y_train_pred, label="Predicted (Training)", color="blue", linestyle="--")
plt.title("Tesla Stock Price Prediction using CNN (Sliding Window) - Training Phase")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# 📌 🔟 결과 시각화 (테스트 데이터 예측 vs 실제값)
plt.figure(figsize=(12, 5))
plt.plot(df["Date"].iloc[split_index+window_size:], y_test_actual, label="Actual (Test)", color="black")
plt.plot(df["Date"].iloc[split_index+window_size:], y_test_pred, label="Predicted (Test)", color="red", linestyle="--")
plt.title("Tesla Stock Price Prediction using CNN (Sliding Window) - Test Phase")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1221 - val_loss: 0.0118
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - val_loss: 0.0022
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 7.7533e-04
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - val_loss: 9.9173e-04
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - val_loss: 7.2957e-04
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 7.4690e-04
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.7525e-04
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - val_loss: 8.0831e-04
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 9.2573e-04
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 9.4174e-04
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - val_loss: 6.7892e-04
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 9.8928e-04
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 6.2620e-04
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 9.1419e-04
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 6.6130e-04
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5555e-04 - val_loss: 6.1502e-04
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0010 - val_loss: 7.1113e-04
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 7.9203e-04
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7776e-04 - val_loss: 7.1959e-04
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.2333e-04
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 7.3790e-04
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.2195e-04
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3338e-04 - val_loss: 6.5553e-04
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 7.4487e-04
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7867e-04 - val_loss: 0.0010
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 6.3172e-04
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6841e-04 - val_loss: 6.4536e-04
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7161e-04 - val_loss: 6.3947e-04
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7598e-04 - val_loss: 6.3900e-04
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010 - val_loss: 6.6201e-04
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1835e-04 - val_loss: 6.2230e-04
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 6.3104e-04
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 6.7398e-04
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7152e-04 - val_loss: 6.7060e-04
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 7.4780e-04
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010 - val_loss: 7.9777e-04
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 7.0572e-04
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8724e-04 - val_loss: 6.3642e-04
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 6.4175e-04
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 6.5389e-04
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6585e-04 - val_loss: 7.6756e-04
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6062e-04 - val_loss: 8.3479e-04
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.5963e-04
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6982e-04 - val_loss: 6.5315e-04
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8986e-04 - val_loss: 6.7247e-04
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 6.3015e-04
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3561e-04 - val_loss: 9.1911e-04
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 7.3063e-04
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 9.6164e-04
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2961e-04 - val_loss: 6.5113e-04
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010 - val_loss: 7.2496e-04
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9359e-04 - val_loss: 6.6069e-04
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9473e-04 - val_loss: 6.2054e-04
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9107e-04 - val_loss: 7.2522e-04
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 8.2960e-04
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8767e-04 - val_loss: 6.8443e-04
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.1880e-04 - val_loss: 0.0012
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 6.2882e-04
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 6.8818e-04
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3276e-04 - val_loss: 7.8690e-04
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 8.0726e-04
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 9.4810e-04
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 6.6272e-04
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7874e-04 - val_loss: 6.6206e-04
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8107e-04 - val_loss: 6.2787e-04
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 6.6188e-04
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 6.4881e-04
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9696e-04 - val_loss: 6.3910e-04
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0194e-04 - val_loss: 8.5346e-04
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 6.8193e-04
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9870e-04 - val_loss: 7.4141e-04
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9645e-04 - val_loss: 0.0017
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - val_loss: 6.1288e-04
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 6.3030e-04
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010 - val_loss: 6.8811e-04
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 8.6283e-04
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 6.5374e-04
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 8.3958e-04
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4284e-04 - val_loss: 6.7431e-04
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1452e-04 - val_loss: 0.0016
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - val_loss: 6.0702e-04
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6083e-04 - val_loss: 6.3664e-04
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2504e-04 - val_loss: 8.9479e-04
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9109e-04 - val_loss: 6.4200e-04
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 📌 Training MSE: 80.5636, R²: 0.9766
# 📌 Test MSE: 54.6746, R²: 0.8231

# %% [markdown]
# # ✅ 🚀 하이퍼파라미터 튜닝이 적용된 CNN 기반 테슬라 주가 예측 코드

# %%
# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (2.32.3)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.14.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 8.9 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
import os
import shutil
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import tensorflow as tf
import keras_tuner as kt  # KerasTuner 추가
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score

# ✅ 📌 기존 하이퍼파라미터 튜닝 파일 삭제 (새로운 탐색을 위해)
tuner_dir = "hyperparameter_tuning/Tesla_CNN_Tuning"
shutil.rmtree(tuner_dir, ignore_errors=True)

# 📌 1️⃣ 테슬라(TSLA) 주가 데이터 다운로드 (최근 2년치)
df = yf.download("TSLA", start="2022-01-01", end="2024-01-01")
df = df.reset_index()

# 📌 2️⃣ 입력 변수(X) 및 출력 변수(y) 생성 (슬라이딩 윈도우)
window_size = 10  # 과거 10일치 데이터를 입력으로 사용

def create_sliding_window_data(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i : i + window_size])  # window_size 만큼의 과거 데이터
        y.append(data[i + window_size])  # 다음날 주가 (타겟)
    return np.array(X), np.array(y)

# `Close`(종가) 데이터를 정규화
scaler = MinMaxScaler()
scaled_close = scaler.fit_transform(df["Close"].values.reshape(-1, 1))

# Sliding Window 적용
X, y = create_sliding_window_data(scaled_close, window_size)

# 📌 3️⃣ 데이터 분할 (80% 학습, 20% 테스트)
split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# 입력 데이터를 CNN 입력 형식 (samples, time steps, features)으로 변환
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# 📌 4️⃣ 하이퍼파라미터 튜닝을 위한 CNN 모델 정의
def build_model(hp):
    model = Sequential()

    # ✅ CNN 필터 수 및 커널 크기 최적화
    model.add(Conv1D(
        filters=hp.Int('filters', min_value=32, max_value=128, step=32),
        kernel_size=hp.Int('kernel_size', min_value=2, max_value=5, step=1),
        activation=hp.Choice('activation', values=['relu', 'tanh']),
        input_shape=(window_size, 1)
    ))

    model.add(Flatten())  # 차원 축소
    model.add(Dense(
        units=hp.Int('dense_units', min_value=16, max_value=128, step=16),
        activation='relu'
    ))

    model.add(Dense(1))  # 출력층

    # ✅ 학습률 최적화
    model.compile(
        optimizer=Adam(hp.Choice('learning_rate', values=[0.001, 0.0005, 0.0001])),
        loss='mse'
    )

    return model

# 📌 5️⃣ KerasTuner를 사용한 하이퍼파라미터 튜닝
tuner = kt.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=10,  # 시도할 모델 개수 증가
    executions_per_trial=3,  # 여러 번 실행 후 최적값 선택
    directory='hyperparameter_tuning',
    project_name='Tesla_CNN_Tuning'
)

# 📌 6️⃣ 최적의 하이퍼파라미터 찾기
tuner.search(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# 📌 7️⃣ 최적 모델 선택
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"📌 최적의 하이퍼파라미터: {best_hps.values}")

best_model = tuner.hypermodel.build(best_hps)

# 📌 8️⃣ 최적 모델 학습
history = best_model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# 📌 🔟 예측 수행
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

# ✅ 📌 예측 데이터 역정규화
y_train_pred = scaler.inverse_transform(y_train_pred)
y_test_pred = scaler.inverse_transform(y_test_pred)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# 📌 1️⃣1️⃣ 성능 평가
train_mse = mean_squared_error(y_train_actual, y_train_pred)
test_mse = mean_squared_error(y_test_actual, y_test_pred)
train_r2 = r2_score(y_train_actual, y_train_pred)
test_r2 = r2_score(y_test_actual, y_test_pred)

print(f"📌 Training MSE: {train_mse:.4f}, R²: {train_r2:.4f}")
print(f"📌 Test MSE: {test_mse:.4f}, R²: {test_r2:.4f}")

# 📌 1️⃣2️⃣ 최적 하이퍼파라미터 성능 시각화
best_trials = tuner.oracle.get_best_trials(num_trials=5)
trial_numbers = range(len(best_trials))
val_losses = [trial.metrics.get_best_value('val_loss') for trial in best_trials]

plt.figure(figsize=(8, 5))
plt.plot(trial_numbers, val_losses, marker='o', linestyle='-', color="blue")
plt.xlabel("Trial Number")
plt.ylabel("Validation Loss")
plt.title("Validation Loss for Best Trials")
plt.xticks(trial_numbers)
plt.show()

# 📌 1️⃣3️⃣ 결과 시각화 (훈련 데이터 예측 vs 실제값)
plt.figure(figsize=(12, 5))
plt.plot(df["Date"].iloc[window_size:split_index+window_size], y_train_actual, label="Actual (Training)", color="black")
plt.plot(df["Date"].iloc[window_size:split_index+window_size], y_train_pred, label="Predicted (Training)", color="blue", linestyle="--")
plt.title("Tesla Stock Price Prediction using CNN (Hyperparameter Tuned) - Training Phase")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# 📌 1️⃣4️⃣ 결과 시각화 (테스트 데이터 예측 vs 실제값)
plt.figure(figsize=(12, 5))
plt.plot(df["Date"].iloc[split_index+window_size:], y_test_actual, label="Actual (Test)", color="black")
plt.plot(df["Date"].iloc[split_index+window_size:], y_test_pred, label="Predicted (Test)", color="red", linestyle="--")
plt.title("Tesla Stock Price Prediction using CNN (Hyperparameter Tuned) - Test Phase")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# Trial 10 Complete [00h 00m 44s]
# val_loss: 0.0006565667960482339
#
# Best val_loss So Far: 0.0006243464110108713
# Total elapsed time: 00h 07m 40s
# 📌 최적의 하이퍼파라미터: {'filters': 96, 'kernel_size': 2, 'activation': 'tanh', 'dense_units': 96, 'learning_rate': 0.001}
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0970 - val_loss: 0.0054
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 8.8986e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 7.7765e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 8.1456e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 7.4279e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 7.4018e-04
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - val_loss: 6.8550e-04
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5623e-04 - val_loss: 0.0015
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 7.3988e-04
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 6.5547e-04
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 9.2162e-04
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 6.8043e-04
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 7.3198e-04
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 7.6293e-04
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 6.4098e-04
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0036e-04 - val_loss: 6.5559e-04
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 6.6397e-04
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 6.5764e-04
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8335e-04 - val_loss: 6.3859e-04
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 6.4079e-04
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 6.8786e-04
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015 - val_loss: 6.1987e-04
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - val_loss: 7.0078e-04
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.4937e-04
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 6.7917e-04
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.5477e-04
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 8.8871e-04
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 6.3052e-04
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 8.4629e-04
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 6.3602e-04
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 6.4578e-04
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.5100e-04
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 7.6546e-04
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 8.9605e-04
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8630e-04 - val_loss: 0.0017
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - val_loss: 6.1824e-04
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 9.0351e-04
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 8.3770e-04
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9583e-04 - val_loss: 7.3622e-04
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.2944e-04
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 6.5470e-04
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.9124e-04
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.4474e-04
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 6.8447e-04
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5104e-04 - val_loss: 6.5847e-04
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5264e-04 - val_loss: 8.1715e-04
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.4364e-04
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1947e-04 - val_loss: 6.3409e-04
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.5292e-04
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 6.4752e-04
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2309e-04 - val_loss: 7.0896e-04
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 6.6265e-04
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 7.1055e-04
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 9.9619e-04
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2116e-04 - val_loss: 6.3628e-04
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 7.1149e-04
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.4268e-04
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 6.9035e-04
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 6.8798e-04
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 6.4954e-04
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - val_loss: 7.1660e-04
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0010 - val_loss: 8.4324e-04
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 8.8871e-04
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 7.0620e-04
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 8.7936e-04
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.4397e-04
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 9.2988e-04
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.7604e-04
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3314e-04 - val_loss: 7.0540e-04
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 7.1803e-04
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 6.5148e-04
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 8.1103e-04
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 9.5249e-04
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 6.5595e-04
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8054e-04 - val_loss: 8.4501e-04
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 6.4675e-04
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0657e-04 - val_loss: 9.4117e-04
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.3845e-04
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5916e-04 - val_loss: 6.4165e-04
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.5761e-04
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 7.1230e-04
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 7.1187e-04
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 6.3708e-04
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5598e-04 - val_loss: 9.0789e-04
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 6.4250e-04
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 📌 Training MSE: 75.7530, R²: 0.9780
# 📌 Test MSE: 54.7174, R²: 0.8230
